# %%
#

import pandas as pd
import numpy as np
volunteer = pd.read_csv('/content/heart failur classification dataset.csv')
volunteer.head(10)
# Out:
#    Unnamed: 0   age  anaemia  ...  smoking  time  DEATH_EVENT
# 0           0  75.0        0  ...       No   4.0            1
# 1           1  55.0        0  ...       No   6.0            1
# 2           2  65.0        0  ...      Yes   7.0            1
# 3           3  50.0        1  ...       No   7.0            1
# 4           4  65.0        1  ...       No   8.0            1
# 5           5  90.0        1  ...      Yes   8.0            1
# 6           6  75.0        1  ...       No  10.0            1
# 7           7  60.0        1  ...      Yes  10.0            1
# 8           8  65.0        0  ...       No  10.0            1
# 9           9  80.0        1  ...      Yes  10.0            1
#
# [10 rows x 14 columns]

# %%
volunteer.shape
# Out:
# (299, 14)

# %%
volunteer.isnull().sum()
# Out:
# Unnamed: 0                  0
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                6
# sex                         0
# smoking                     0
# time                        7
# DEATH_EVENT                 0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

impute = SimpleImputer(missing_values=np.nan, strategy='mean')

impute.fit(volunteer[['time']])

volunteer['time'] = impute.transform(volunteer[['time']])

# %%
from sklearn.impute import SimpleImputer

impute = SimpleImputer(missing_values=np.nan, strategy='mean')

impute.fit(volunteer[['serum_sodium']])

volunteer['serum_sodium'] = impute.transform(volunteer[['serum_sodium']])

# %%
volunteer.isnull().sum()
# Out:
# Unnamed: 0                  0
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
volunteer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                299 non-null    int64
#  1   age                       299 non-null    float64
#  2   anaemia                   299 non-null    int64
#  3   creatinine_phosphokinase  299 non-null    int64
#  4   diabetes                  299 non-null    int64
#  5   ejection_fraction         299 non-null    int64
#  6   high_blood_pressure       299 non-null    int64
#  7   platelets                 299 non-null    float64
#  8   serum_creatinine          299 non-null    float64
#  9   serum_sodium              299 non-null    float64
#  10  sex                       299 non-null    object
#  11  smoking                   299 non-null    object
#  12  time                      299 non-null    float64
# ...

# %%
volunteer.head()
# Out:
#    Unnamed: 0   age  anaemia  ...  smoking  time  DEATH_EVENT
# 0           0  75.0        0  ...       No   4.0            1
# 1           1  55.0        0  ...       No   6.0            1
# 2           2  65.0        0  ...      Yes   7.0            1
# 3           3  50.0        1  ...       No   7.0            1
# 4           4  65.0        1  ...       No   8.0            1
#
# [5 rows x 14 columns]

# %%
from sklearn.preprocessing import LabelEncoder


enc = LabelEncoder()


volunteer['sex_enc'] = enc.fit_transform(volunteer['sex'])
volunteer['smoking_enc']=enc.fit_transform(volunteer['smoking'])


# Compare the two columns
print(volunteer[['sex', 'sex_enc']].head())
# Out:
#       sex  sex_enc
# 0    Male        1
# 1    Male        1
# 2    Male        1
# 3    Male        1
# 4  Female        0

# %%
print(volunteer[['smoking','smoking_enc']].head())
# Out:
#   smoking  smoking_enc
# 0      No            0
# 1      No            0
# 2     Yes            1
# 3      No            0
# 4      No            0

# %%
volunteer.head()
# Out:
#    Unnamed: 0   age  anaemia  ...  DEATH_EVENT  sex_enc  smoking_enc
# 0           0  75.0        0  ...            1        1            0
# 1           1  55.0        0  ...            1        1            0
# 2           2  65.0        0  ...            1        1            1
# 3           3  50.0        1  ...            1        1            0
# 4           4  65.0        1  ...            1        0            0
#
# [5 rows x 16 columns]

# %%
volunteer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                299 non-null    int64
#  1   age                       299 non-null    float64
#  2   anaemia                   299 non-null    int64
#  3   creatinine_phosphokinase  299 non-null    int64
#  4   diabetes                  299 non-null    int64
#  5   ejection_fraction         299 non-null    int64
#  6   high_blood_pressure       299 non-null    int64
#  7   platelets                 299 non-null    float64
#  8   serum_creatinine          299 non-null    float64
#  9   serum_sodium              299 non-null    float64
#  10  sex                       299 non-null    object
#  11  smoking                   299 non-null    object
#  12  time                      299 non-null    float64
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
X_train, X_test, y_train, y_test = train_test_split(volunteer, volunteer, random_state=1)
print(X_train.shape)
print(X_test.shape)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)

print("per-feature minimum after scaling:\n {}".format(X_train_scaled.min(axis=0)))

print("per-feature maximum after scaling:\n {}".format(X_train_scaled.max(axis=0)))
# Out:
# (224, 14)
# (75, 14)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-bb02d82af6fc> in <module>()
#       6 from sklearn.preprocessing import MinMaxScaler
#       7 scaler = MinMaxScaler()
# ----> 8 scaler.fit(X_train)
#       9 X_train_scaled = scaler.transform(X_train)
#      10
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     337         # Reset internal state before fitting
#     338         self._reset()
# --> 339         return self.partial_fit(X, y)
#     340
#     341     def partial_fit(self, X, y=None):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y)
#     371         X = check_array(X,
#     372                         estimator=self, dtype=FLOAT_DTYPES,
# --> 373                         force_all_finite="allow-nan")
#     374
# ...

# %% [markdown]
# # New section
